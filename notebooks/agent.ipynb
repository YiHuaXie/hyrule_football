# %%
from hyrule_football.agents.hyrule_agent import HyruleAgent

agent = HyruleAgent()
agent.run_agent("查询所有比赛", "nero_session1")
# agent = HyruleAgent()
# agent.run_agent("获取意甲的比赛", "nero_session1")
# agent = HyruleAgent()
# agent.run_agent("查询所有意甲的比赛的赔率", "nero_session1")
# agent.run_agent("", "nero_session1")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from hyrule_football.agents.hyrule_agent import HyruleAgent
#       3 agent = HyruleAgent()
#       4 agent.run_agent("查询所有比赛", "nero_session1")
#
# File ~/Programs/AI/hyrule-football/hyrule_football/agents/hyrule_agent.py:8
#       6 from hyrule_football.prompts.hyrule_prompt import HyrulePrompt
#       7 from hyrule_football.memory.chat_memory import ChatMemory
# ----> 8 from hyrule_football.tools import (
#       9     get_match_list,
#      10     get_match_for_team,
#      11     get_match_for_matchup,
#      12     get_odds_info_for_match,
#      13     plan_match_odds_query,
#      14     update_match_list,
#      15 )
#      17 import os
#      19 _load_dotenv()
#
# File ~/Programs/AI/hyrule-football/hyrule_football/tools/__init__.py:8
#       1 from .match_tools import (
#       2     get_match_list,
#       3     get_match_for_team,
#       4     get_match_for_matchup,
#       5     update_match_list,
#       6 )
# ----> 8 from .odds_tools import plan_match_odds_query, get_odds_info_for_match
#      10 __all__ = [
#      11     "plan_match_odds_query",
#      12     "get_odds_info_for_match",
#    (...)     16     "get_match_for_matchup",
#      17 ]
#
# File ~/Programs/AI/hyrule-football/hyrule_football/tools/odds_tools.py:3
#       1 from langchain.tools import tool
#       2 from hyrule_football.utils import get_logger
# ----> 3 from hyrule_football.models import BasedMatchOddsInfo, get_company_by_name, MatchInfo, Company
#       4 from hyrule_football.core.match_service import get_match_for_name
#       5 from hyrule_football.core.odds_service import get_odds_for_match
#
# ModuleNotFoundError: No module named 'hyrule_football.models'

# %%
text = '## 意甲比赛赔率分析\n\n### 比赛一：乌迪内斯 VS 博洛尼亚\n\n#### 格局数据分析\n\n### bet365\n- **初始让球方**：博洛尼亚\n- **初始格局**：高-低-中\n- **当前让球方**：博洛尼亚\n- **当前格局**：低-中-高\n\n### 威廉希尔\n- **初始让球方**：博洛尼亚\n- **初始格局**：高-低-高\n- **当前让球方**：博洛尼亚\n- **当前格局**：高-低-中\n\n#### 基于主队（乌迪内斯）的盘口数据\n\n**bet365**\n- **初始欧指**：胜3.7 平3.2 负2.1（返奖率94.43%）\n- **即时欧指**：胜3.4 平3.4 负2.15（返奖率94.94%）\n- **初始亚盘**：受让0.5球 低水（返奖率95.84%）\n- **即时亚盘**：受让0.25球 中水（返奖率96.5%）\n\n**威廉希尔**\n- **初始欧指**：胜3.7 平3.1 负2.05（返奖率92.54%）\n- **即时欧指**：胜3.3 平3.0 负2.2（返奖率91.67%）\n- **初始亚盘**：受让0.5球 低水（返奖率92.76%）\n- **即时亚盘**：受让0.25球 低水（返奖率90.0%）\n\n---\n\n### 比赛二：卡利亚里 VS 热那亚\n\n#### 格局数据分析\n\n### bet365\n- **初始让球方**：卡利亚里\n- **初始格局**：高-低-中\n- **当前让球方**：卡利亚里\n- **当前格局**：高-低-高\n\n### 威廉希尔\n- **初始让球方**：卡利亚里\n- **初始格局**：高-低-高\n- **当前让球方**：卡利亚里\n- **当前格局**：高-低-中\n\n#### 基于主队（卡利亚里）的盘口数据\n\n**bet365**\n- **初始欧指**：胜2.8 平3.0 负2.7（返奖率94.26%）\n- **即时欧指**：胜3.0 平2.9 负2.7（返奖率95.37%）\n- **初始亚盘**：平手盘 低水（返奖率96.24%）\n- **即时亚盘**：平手盘 高水（返奖率95.84%）\n\n**威廉希尔**\n- **初始欧指**：胜2.63 平2.9 负2.88（返奖率93.26%）\n- **即时欧指**：胜2.9 平2.75 负2.7（返奖率92.69%）\n- **初始亚盘**：平手盘 低水（返奖率89.82%）\n- **即时亚盘**：平手盘 低水（返奖率90.05%）\n\n以上是当前意甲两场比赛的完整赔率分析数据。'
print(text)
# Out:
# ## 意甲比赛赔率分析
#
# ### 比赛一：乌迪内斯 VS 博洛尼亚
#
# #### 格局数据分析
#
# ### bet365
# - **初始让球方**：博洛尼亚
# - **初始格局**：高-低-中
# - **当前让球方**：博洛尼亚
# - **当前格局**：低-中-高
#
# ### 威廉希尔
# - **初始让球方**：博洛尼亚
# - **初始格局**：高-低-高
# - **当前让球方**：博洛尼亚
# - **当前格局**：高-低-中
#
# #### 基于主队（乌迪内斯）的盘口数据
#
# **bet365**
# - **初始欧指**：胜3.7 平3.2 负2.1（返奖率94.43%）
# - **即时欧指**：胜3.4 平3.4 负2.15（返奖率94.94%）
# - **初始亚盘**：受让0.5球 低水（返奖率95.84%）
# - **即时亚盘**：受让0.25球 中水（返奖率96.5%）
#
# **威廉希尔**
# - **初始欧指**：胜3.7 平3.1 负2.05（返奖率92.54%）
# - **即时欧指**：胜3.3 平3.0 负2.2（返奖率91.67%）
# - **初始亚盘**：受让0.5球 低水（返奖率92.76%）
# - **即时亚盘**：受让0.25球 低水（返奖率90.0%）
#
# ---
#
# ### 比赛二：卡利亚里 VS 热那亚
#
# #### 格局数据分析
#
# ### bet365
# - **初始让球方**：卡利亚里
# - **初始格局**：高-低-中
# - **当前让球方**：卡利亚里
# - **当前格局**：高-低-高
#
# ### 威廉希尔
# - **初始让球方**：卡利亚里
# - **初始格局**：高-低-高
# - **当前让球方**：卡利亚里
# - **当前格局**：高-低-中
#
# #### 基于主队（卡利亚里）的盘口数据
#
# **bet365**
# - **初始欧指**：胜2.8 平3.0 负2.7（返奖率94.26%）
# - **即时欧指**：胜3.0 平2.9 负2.7（返奖率95.37%）
# - **初始亚盘**：平手盘 低水（返奖率96.24%）
# - **即时亚盘**：平手盘 高水（返奖率95.84%）
#
# **威廉希尔**
# - **初始欧指**：胜2.63 平2.9 负2.88（返奖率93.26%）
# - **即时欧指**：胜2.9 平2.75 负2.7（返奖率92.69%）
# - **初始亚盘**：平手盘 低水（返奖率89.82%）
# - **即时亚盘**：平手盘 低水（返奖率90.05%）
#
# 以上是当前意甲两场比赛的完整赔率分析数据。
