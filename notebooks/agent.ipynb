# %%
from hyrule_football.agents.hyrule_agent import HyruleAgent

agent = HyruleAgent()
agent.run_agent("所有赛事", "123")
# Out:
# [values] {'messages': [HumanMessage(content='所有赛事', additional_kwargs={}, response_metadata={}, id='2cd9a054-865d-4274-ad5e-ed845b9f3188')]}
# ...
