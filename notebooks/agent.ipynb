# %%
from hyrule_football.agents.hyrule_agent import HyruleAgent

agent = HyruleAgent()
agent.run_agent("所有比赛", "123")
# Out:
# [values] {'messages': [HumanMessage(content='更新赛事', additional_kwargs={}, response_metadata={}, id='97ad9382-6d73-47c2-8ea0-56846bf356b7')]}
# ...
