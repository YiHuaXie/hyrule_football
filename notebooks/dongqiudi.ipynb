# %%
from  hyrule_football.service.dqd_service import request_daily_match_list, request_match_analysis, request_team_detail
import json
match_list = request_daily_match_list()

# fixed_match = [m for m in match_list if m.get("team_A_name") == "斯图加特" or m.get("team_B_name") == "斯图加特"]
# if not fixed_match:
#     print("❌ 未找到比赛")
#     exit(1)

# fixed_match = fixed_match[0]
# print(fixed_match["team_A_name"])
# print("====比赛信息====") 
# match_detail = request_match_analysis(fixed_match["match_id"])
# print(json.dumps(match_detail, indent=4, ensure_ascii=False))
# print("====球队信息====")
# team_a_detail = request_team_detail(fixed_match["team_A_id"])
# team_members = team_a_detail.get("teamMemberData")
# 前锋 = [m.get("person_name") for m in team_members if m.get("title") == "前锋"]
# print(f"前锋 = {前锋}")
# Out:
# 第一组数据：
# [
#     {
#         "relate_type": "match",
#         "relate_id": "54327598",
#         "match_id": "54327598",
#         "team_A_id": "50001260",
#         "team_A_name": "托卢卡体育",
#         "team_A_logo": "https://sd.qunliao.info/fastdfs3/M00/AF/AE/ChOxM1w8DVmAC1EoAABY2suDUFQ944.png",
#         "team_B_id": "50002608",
#         "team_B_name": "蒙特雷",
#         "team_B_logo": "https://sd.qunliao.info/fastdfs7/M00/F1/09/rBUC6GhQ1emAJqJAAAAxjMzAgug535.png",
#         "date_utc": "2025-12-07",
#         "bk_logo": "",
#         "time_utc": "09:00",
#         "start_play": "2025-12-07 01:00:00",
#         "end_play": "2025-12-07 03:02:00",
#         "sort_timestamp": 1765040400,
#         "status": "Played",
#         "fs_A": "3",
#         "fs_B": "2",
#         "ps_A": "",
#         "ps_B": "",
#         "ets_A": "3",
#         "ets_B": "2",
#         "ags_A": "3",
#         "ags_B": "3",
#         "gameweek": "",
#         "suretime": "1",
#         "playing_time": "120",
# ...

# %%
from hyrule_football.service.dqd_service import request_app_daily_match_list
import json
data = request_app_daily_match_list()
print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# {
#     "start": "",
#     "time_stamp": 0,
#     "matches": [
#         {
#             "match_id": "54223145",
#             "competition": {
#                 "id": "10",
#                 "name": "意乙",
#                 "area_id": "100",
#                 "area_name": "意大利",
#                 "color": "#66CCFF",
#                 "sort": "9999"
#             },
#             "status": "Fixture",
#             "minute": "0",
#             "minute_str": "",
#             "injury_time": 0,
#             "start_play": "2025-12-08 14:00:00",
#             "match_timestamp": 1765202400,
#             "update_timestamp": 1765176023,
#             "period": "1H",
#             "cmp_type": "soccer",
#             "team_A": {
#                 "id": "2542",
#                 "name": "弗罗西诺内",
#                 "logo": "https://sd.qunliao.info/fastdfs3/M00/B5/81/ChOxM1xC2XCAbqftAAAXZx9yU-w515.png",
#                 "fs": "",
#                 "hts": "",
# ...
