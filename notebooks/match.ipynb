# %%
from dotenv import load_dotenv
load_dotenv()
from app.core.match_service import request_all_match_list
from app.store import get_match_store

request_all_match_list()

print(get_match_store().get_match("1739390"))
# Out:
# 2025-11-24 22:30:06 - app.core.api_service - INFO - ✅ 获取所有赛事成功：[{'awayTeam': '伊蒂哈德', 'leagueColor': '#0000DB', 'matchState': 0, 'focus': False, 'distribution': [{'number': '6.81', 'option': '胜'}, {'number': '1.98', 'option': '平'}, {'number': '4.83', 'option': '负'}], 'viewpointsAsian': [{'amount': 13, 'nowBet': '受平手/半球', 'nowOddsUp': '2.00', 'nowOddsDown': '1.80'}], 'score': '0:0', 'awayRedCard': 0, 'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130912172913.png', 'asianOdds': {'nowBet': '受平手/半球', 'handicap': '*0.25', 'nowOddsUp': '2.00', 'nowOddsDown': '1.80'}, 'leagueId': 144, 'homeRedCard': 0, 'awayRank': '7', 'homeTeam': '艾杜哈尼', 'season': '2025-2026', 'homeTeamId': 13708, 'matchId': 1738637, 'matchStateShow': '未开赛', 'matchNoteCount': 14, 'handicap': '1', 'jczqOdds': {'0': '1.87', '1': '3.75', '3': '3.05'}, 'league': '亚冠精英', 'euroOdds': {'0': '2.04', '1': '3.79', '3': '3.05'}, 'matchTime': 1764000000000, 'homeLogo': 'https://alphaball-production.o
# ...

# %%
from dotenv import load_dotenv
load_dotenv()

# from app.tools import get_match_for_name
# print(get_match_for_name("桑托斯 VS 米拉索"))
# print(get_match_for_name("皇马"))
# print(get_match_for_name("桑托斯"))
# print(get_match_for_name("米拉索"))
# print(get_match_for_name("桑托斯vs米拉索"))
# print(get_match_for_name("桑托斯Vs 米拉索"))
# print(get_match_for_name("桑托斯&格雷米奥")) # 暂不支持吧
# Out:
# 2025-11-19 14:52:54 - app.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯 VS 米拉索
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - app.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：皇马
# 没有找到相关比赛，确认「皇马」比赛在「赛事列表」中
# 2025-11-19 14:52:54 - app.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - app.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：米拉索
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - app.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯vs米拉索
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - app.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯Vs 米拉索
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - app.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯&格雷米奥
# 没有找到相关比赛，确认「桑托斯&格雷米奥」比赛在「赛事列表」中
