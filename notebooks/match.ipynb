# %%
from hyrule_football.service.match_service import new_sync_daily_match_list

new_sync_daily_match_list()
# Out:
# 2025-12-08 18:23:33 - hyrule_football.service.oh_service - INFO - POST http://backend.aiball365.com/web/matchLiveList, params={'channel': 'web', 'os': 'browser', 'matchType': 1, 'page': 0, 'size': 10000, 'type': 1}
# 英冠:查尔顿 VS 朴茨茅斯
# 韩K联:水原城 VS 富川FC
# 意甲:比萨 VS 帕尔马
# 意甲:乌迪内斯 VS 热那亚
# 意甲:都灵 VS AC米兰
# 法乙:兰斯 VS 拉瓦勒
# 英超:狼队 VS 曼彻斯特联
# 西甲:奥萨苏纳 VS 莱万特
# 葡超:吉马雷斯 VS 吉维森特
# 欧冠杯:阿拉木图凯拉 VS 奥林匹亚科斯
# 欧冠杯:拜仁慕尼黑 VS 里斯本竞技
# 欧冠杯:巴塞罗那 VS 法兰克福
# 欧冠杯:亚特兰大 VS 切尔西
# 欧冠杯:圣吉罗斯 VS 马赛
# 欧冠杯:摩纳哥 VS 加拉塔萨雷
# 欧冠杯:埃因霍温 VS 马德里竞技
# 欧冠杯:国际米兰 VS 利物浦
# 欧冠杯:托特纳姆热刺 VS 布拉格斯拉维
# [MatchModel(season='2025-2026', league='英冠', league_id='32', league_round='第19轮', match_id='1678482', dqd_match_id=None, match_time='2025-12-06 20:30', match_state=4, match_state_show='腰斩', home='查尔顿', home_rank='17', home_id='13', home_dqd_team_id=None, away='朴茨茅斯', away_id='19', away_rank='22', away_dqd_team_id=None),
# ...
