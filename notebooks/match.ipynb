# %%
from hyrule_football.service.api_service import request_all_match_list, request_league_list, request_hot_match_list
request_hot_match_list()
# Out:
# [{'awayTeam': '墨尔本胜利',
#   'leagueColor': '#FF7000',
#   'matchState': 0,
#   'focus': False,
#   'viewpointsAsian': [{'amount': 12,
#     'nowBet': '平手',
#     'nowOddsUp': '1.78',
#     'nowOddsDown': '2.07'},
#    {'amount': 3,
#     'nowBet': '平手/半球',
#     'nowOddsUp': '2.09',
#     'nowOddsDown': '1.79'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130923112350.png',
#   'asianOdds': {'nowBet': '平手',
#    'handicap': '0',
#    'nowOddsUp': '1.78',
#    'nowOddsDown': '2.07'},
#   'leagueId': 167969,
#   'awayRank': '10',
#   'homeTeam': '布里斯班狮吼',
#   'season': '2025-2026',
#   'homeTeamId': 2471,
#   'matchId': 1748183,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 23,
#   'handicap': '-1',
#   'jczqOdds': {'0': '2.70', '1': '3.25', '3': '2.22'},
#   'league': '澳超',
#   'euroOdds': {'0': '2.74', '1': '3.42', '3': '2.42'},
#   'matchTime': 1764318900000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20181011191538.jpg',
#   'jcMatchNo': '20251128001',
#   'minute': "0'",
#   'homeRank': '5',
#   'round': '第6轮',
#   'matchNo': '20251128001',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '4.70'}, {'1': '4.00'}, {'0': '1.50'}],
#    'spfOdds': [{'3': '2.22'}, {'1': '3.25'}, {'0': '2.70'}]},
#   'awayTeamId': 2458,
#   'dc': 1},
#  {'awayTeam': '柏德博恩',
#   'leagueColor': '#CA00CA',
#   'matchState': 0,
#   'focus': False,
#   'viewpointsAsian': [{'amount': 15,
#     'nowBet': '平手',
#     'nowOddsUp': '1.79',
#     'nowOddsDown': '2.06'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20180921192806.jpg',
#   'asianOdds': {'nowBet': '平手',
#    'handicap': '0',
#    'nowOddsUp': '1.79',
#    'nowOddsDown': '2.06'},
#   'leagueId': 9,
#   'awayRank': '1',
#   'homeTeam': '沙尔克04',
#   'season': '2025-2026',
#   'homeTeamId': 151,
#   'matchId': 1680781,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 5,
#   'handicap': '1',
#   'jczqOdds': {'0': '2.50', '1': '3.20', '3': '2.40'},
#   'league': '德乙',
#   'euroOdds': {'0': '2.80', '1': '3.10', '3': '2.53'},
#   'matchTime': 1764351000000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013119145317.jpg',
#   'jcMatchNo': '20251128002',
#   'minute': "0'",
#   'homeRank': '2',
#   'round': '第14轮',
#   'matchNo': '20251128002',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '1.40'}, {'1': '4.25'}, {'0': '5.55'}],
#    'spfOdds': [{'3': '2.40'}, {'1': '3.20'}, {'0': '2.50'}]},
#   'awayTeamId': 1474,
#   'dc': 0},
#  {'awayTeam': '卡尔斯鲁厄',
#   'leagueColor': '#CA00CA',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '11.84', 'option': '负'},
#    {'number': '0.85', 'option': '胜'},
#    {'number': '10.98', 'option': '平'}],
#   'viewpointsAsian': [{'amount': 5,
#     'nowBet': '一球',
#     'nowOddsUp': '1.79',
#     'nowOddsDown': '2.00'},
#    {'amount': 10,
#     'nowBet': '一球/球半',
#     'nowOddsUp': '2.01',
#     'nowOddsDown': '1.85'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013120111953.jpg',
#   'asianOdds': {'nowBet': '一球/球半',
#    'handicap': '1.25',
#    'nowOddsUp': '2.01',
#    'nowOddsDown': '1.85'},
#   'leagueId': 9,
#   'awayRank': '8',
#   'homeTeam': '汉诺威96',
#   'season': '2025-2026',
#   'homeTeamId': 156,
#   'matchId': 1680778,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 2,
#   'handicap': '-1',
#   'jczqOdds': {'0': '5.40', '1': '4.45', '3': '1.39'},
#   'league': '德乙',
#   'euroOdds': {'0': '5.49', '1': '4.51', '3': '1.49'},
#   'matchTime': 1764351000000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/201312092606.jpg',
#   'jcMatchNo': '20251128003',
#   'minute': "0'",
#   'homeRank': '5',
#   'round': '第14轮',
#   'matchNo': '20251128003',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '2.25'}, {'1': '3.43'}, {'0': '2.55'}],
#    'spfOdds': [{'3': '1.39'}, {'1': '4.45'}, {'0': '5.40'}]},
#   'awayTeamId': 458,
#   'dc': 0},
#  {'awayTeam': '格勒诺布尔',
#   'leagueColor': '#297CA5',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '3.71', 'option': '胜'},
#    {'number': '0.12', 'option': '平'},
#    {'number': '3.83', 'option': '负'}],
#   'viewpointsAsian': [{'amount': 14,
#     'nowBet': '半球',
#     'nowOddsUp': '1.93',
#     'nowOddsDown': '1.85'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013211151140.jpg',
#   'asianOdds': {'nowBet': '半球',
#    'handicap': '0.5',
#    'nowOddsUp': '1.93',
#    'nowOddsDown': '1.85'},
#   'leagueId': 43,
#   'awayRank': '12',
#   'homeTeam': '安尼茨',
#   'season': '2025-2026',
#   'homeTeamId': 6291,
#   'matchId': 1779277,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 1,
#   'handicap': '-1',
#   'jczqOdds': {'0': '3.85', '1': '3.10', '3': '1.83'},
#   'league': '法国杯',
#   'euroOdds': {'0': '3.76', '1': '3.18', '3': '1.94'},
#   'matchTime': 1764356400000,
#   'homeLogo': '',
#   'jcMatchNo': '20251128004',
#   'minute': "0'",
#   'homeRank': '10',
#   'round': '第八圈',
#   'matchNo': '20251128004',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '3.80'}, {'1': '3.35'}, {'0': '1.76'}],
#    'spfOdds': [{'3': '1.83'}, {'1': '3.10'}, {'0': '3.85'}]},
#   'awayTeamId': 359,
#   'dc': 0},
#  {'awayTeam': '海伦芬',
#   'leagueColor': '#FF6699',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '16.36', 'option': '胜'},
#    {'number': '0.57', 'option': '平'},
#    {'number': '15.79', 'option': '负'}],
#   'viewpointsAsian': [{'amount': 13,
#     'nowBet': '受半球/一球',
#     'nowOddsUp': '1.95',
#     'nowOddsDown': '1.91'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404170243.jpg',
#   'asianOdds': {'nowBet': '受半球/一球',
#    'handicap': '*0.75',
#    'nowOddsUp': '1.95',
#    'nowOddsDown': '1.91'},
#   'leagueId': 16,
#   'awayRank': '9',
#   'homeTeam': '泽沃勒',
#   'season': '2025-2026',
#   'homeTeamId': 378,
#   'matchId': 1671904,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 7,
#   'handicap': '1',
#   'jczqOdds': {'0': '1.64', '1': '3.85', '3': '3.85'},
#   'league': '荷甲',
#   'euroOdds': {'0': '1.75', '1': '3.97', '3': '4.09'},
#   'matchTime': 1764356400000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404171623.jpg',
#   'jcMatchNo': '20251128005',
#   'minute': "0'",
#   'homeRank': '15',
#   'round': '第14轮',
#   'matchNo': '20251128005',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '1.95'}, {'1': '3.60'}, {'0': '2.95'}],
#    'spfOdds': [{'3': '3.85'}, {'1': '3.85'}, {'0': '1.64'}]},
#   'awayTeamId': 217,
#   'dc': 0},
#  {'awayTeam': '威廉二世',
#   'leagueColor': '#FFC4E1',
#   'matchState': 0,
#   'focus': False,
#   'viewpointsAsian': [{'amount': 15,
#     'nowBet': '平手',
#     'nowOddsUp': '1.97',
#     'nowOddsDown': '1.85'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404165903.jpg',
#   'asianOdds': {'nowBet': '平手',
#    'handicap': '0',
#    'nowOddsUp': '1.97',
#    'nowOddsDown': '1.85'},
#   'leagueId': 17,
#   'awayRank': '7',
#   'homeTeam': '邓伯什',
#   'season': '2025-2026',
#   'homeTeamId': 235,
#   'matchId': 1671570,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 2,
#   'handicap': '-1',
#   'jczqOdds': {'0': '2.40', '1': '3.60', '3': '2.30'},
#   'league': '荷乙',
#   'euroOdds': {'0': '2.38', '1': '3.66', '3': '2.53'},
#   'matchTime': 1764356400000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404173054.jpg',
#   'jcMatchNo': '20251128006',
#   'minute': "0'",
#   'homeRank': '6',
#   'round': '第18轮',
#   'matchNo': '20251128006',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '4.65'}, {'1': '4.30'}, {'0': '1.47'}],
#    'spfOdds': [{'3': '2.30'}, {'1': '3.60'}, {'0': '2.40'}]},
#   'awayTeamId': 200,
#   'dc': 0},
#  {'awayTeam': '海牙',
#   'leagueColor': '#FFC4E1',
#   'matchState': 0,
#   'focus': False,
#   'viewpointsAsian': [{'amount': 14,
#     'nowBet': '受一球',
#     'nowOddsUp': '1.85',
#     'nowOddsDown': '1.97'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404171352.jpg',
#   'asianOdds': {'nowBet': '受一球',
#    'handicap': '*1',
#    'nowOddsUp': '1.85',
#    'nowOddsDown': '1.97'},
#   'leagueId': 17,
#   'awayRank': '1',
#   'homeTeam': '芬洛',
#   'season': '2025-2026',
#   'homeTeamId': 250,
#   'matchId': 1671573,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 1,
#   'handicap': '1',
#   'jczqOdds': {'0': '1.40', '1': '4.45', '3': '5.25'},
#   'league': '荷乙',
#   'euroOdds': {'0': '1.53', '1': '4.26', '3': '5.01'},
#   'matchTime': 1764356400000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404171446.jpg',
#   'jcMatchNo': '20251128007',
#   'minute': "0'",
#   'homeRank': '12',
#   'round': '第18轮',
#   'matchNo': '20251128007',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '2.48'}, {'1': '3.86'}, {'0': '2.14'}],
#    'spfOdds': [{'3': '5.25'}, {'1': '4.45'}, {'0': '1.40'}]},
#   'awayTeamId': 230,
#   'dc': 0},
#  {'awayTeam': '赫尔蒙德',
#   'leagueColor': '#FFC4E1',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '16.72', 'option': '负'},
#    {'number': '5.14', 'option': '胜'},
#    {'number': '11.57', 'option': '平'}],
#   'viewpointsAsian': [{'amount': 15,
#     'nowBet': '一球',
#     'nowOddsUp': '1.86',
#     'nowOddsDown': '1.96'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404172804.jpg',
#   'asianOdds': {'nowBet': '一球',
#    'handicap': '1',
#    'nowOddsUp': '1.86',
#    'nowOddsDown': '1.96'},
#   'leagueId': 17,
#   'awayRank': '11',
#   'homeTeam': '坎布尔',
#   'season': '2025-2026',
#   'homeTeamId': 267,
#   'matchId': 1671569,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 3,
#   'handicap': '-1',
#   'jczqOdds': {'0': '5.25', '1': '4.35', '3': '1.41'},
#   'league': '荷乙',
#   'euroOdds': {'0': '5.35', '1': '4.39', '3': '1.49'},
#   'matchTime': 1764356400000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20181102103457.png',
#   'jcMatchNo': '20251128008',
#   'minute': "0'",
#   'homeRank': '2',
#   'round': '第18轮',
#   'matchNo': '20251128008',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '2.19'}, {'1': '3.70'}, {'0': '2.49'}],
#    'spfOdds': [{'3': '1.41'}, {'1': '4.35'}, {'0': '5.25'}]},
#   'awayTeamId': 242,
#   'dc': 0},
#  {'awayTeam': 'RB莱比锡',
#   'leagueColor': '#990099',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '2.66', 'option': '平'},
#    {'number': '0.36', 'option': '负'},
#    {'number': '3.03', 'option': '胜'}],
#   'viewpointsAsian': [{'amount': 14,
#     'nowBet': '受平手/半球',
#     'nowOddsUp': '1.85',
#     'nowOddsDown': '2.02'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20180921105900.png',
#   'asianOdds': {'nowBet': '受平手/半球',
#    'handicap': '*0.25',
#    'nowOddsUp': '1.85',
#    'nowOddsDown': '2.02'},
#   'leagueId': 8,
#   'awayRank': '2',
#   'homeTeam': '门兴格拉德巴',
#   'season': '2025-2026',
#   'homeTeamId': 109,
#   'matchId': 1681064,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 7,
#   'handicap': '1',
#   'jczqOdds': {'0': '2.01', '1': '3.73', '3': '2.75'},
#   'league': '德甲',
#   'euroOdds': {'0': '2.23', '1': '3.80', '3': '2.87'},
#   'matchTime': 1764358200000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013119144848.jpg',
#   'jcMatchNo': '20251128009',
#   'minute': "0'",
#   'homeRank': '12',
#   'round': '第12轮',
#   'matchNo': '20251128009',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '1.60'}, {'1': '4.15'}, {'0': '3.80'}],
#    'spfOdds': [{'3': '2.75'}, {'1': '3.73'}, {'0': '2.01'}]},
#   'awayTeamId': 11803,
#   'dc': 0},
#  {'awayTeam': '森索罗',
#   'leagueColor': '#0088FF',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '11.39', 'option': '平'},
#    {'number': '9.04', 'option': '胜'},
#    {'number': '20.43', 'option': '负'}],
#   'viewpointsAsian': [{'amount': 13,
#     'nowBet': '半球/一球',
#     'nowOddsUp': '1.89',
#     'nowOddsDown': '1.98'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013121192851.jpg',
#   'asianOdds': {'nowBet': '半球/一球',
#    'handicap': '0.75',
#    'nowOddsUp': '1.89',
#    'nowOddsDown': '1.98'},
#   'leagueId': 29,
#   'awayRank': '9',
#   'homeTeam': '科莫',
#   'season': '2025-2026',
#   'homeTeamId': 1220,
#   'matchId': 1666897,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 4,
#   'handicap': '-1',
#   'jczqOdds': {'0': '5.00', '1': '3.62', '3': '1.53'},
#   'league': '意甲',
#   'euroOdds': {'0': '5.23', '1': '3.78', '3': '1.66'},
#   'matchTime': 1764359100000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013121214855.jpg',
#   'jcMatchNo': '20251128010',
#   'minute': "0'",
#   'homeRank': '6',
#   'round': '第13轮',
#   'matchNo': '20251128010',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '2.83'}, {'1': '3.20'}, {'0': '2.16'}],
#    'spfOdds': [{'3': '1.53'}, {'1': '3.62'}, {'0': '5.00'}]},
#   'awayTeamId': 2497,
#   'dc': 1},
#  {'awayTeam': '雷恩',
#   'leagueColor': '#663333',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '0.70', 'option': '胜'},
#    {'number': '0.46', 'option': '负'},
#    {'number': '1.16', 'option': '平'}],
#   'viewpointsAsian': [{'amount': 14,
#     'nowBet': '受半球',
#     'nowOddsUp': '1.91',
#     'nowOddsDown': '1.94'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/201327164804.jpg',
#   'asianOdds': {'nowBet': '受半球',
#    'handicap': '*0.5',
#    'nowOddsUp': '1.91',
#    'nowOddsDown': '1.94'},
#   'leagueId': 11,
#   'awayRank': '6',
#   'homeTeam': '梅斯',
#   'season': '2025-2026',
#   'homeTeamId': 193,
#   'matchId': 1681409,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 5,
#   'handicap': '1',
#   'jczqOdds': {'0': '1.74', '1': '3.60', '3': '3.61'},
#   'league': '法甲',
#   'euroOdds': {'0': '1.93', '1': '3.72', '3': '3.66'},
#   'matchTime': 1764359100000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/201327160357.jpg',
#   'jcMatchNo': '20251128011',
#   'minute': "0'",
#   'homeRank': '17',
#   'round': '第14轮',
#   'matchNo': '20251128011',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '1.83'}, {'1': '3.65'}, {'0': '3.25'}],
#    'spfOdds': [{'3': '3.61'}, {'1': '3.60'}, {'0': '1.74'}]},
#   'awayTeamId': 233,
#   'dc': 1},
#  {'awayTeam': '伊普斯维奇',
#   'leagueColor': '#cc3300',
#   'matchState': 0,
#   'focus': False,
#   'viewpointsAsian': [{'amount': 14,
#     'nowBet': '受一球',
#     'nowOddsUp': '1.82',
#     'nowOddsDown': '2.02'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013121233044.png',
#   'asianOdds': {'nowBet': '受一球',
#    'handicap': '*1',
#    'nowOddsUp': '1.82',
#    'nowOddsDown': '2.02'},
#   'leagueId': 32,
#   'awayRank': '5',
#   'homeTeam': '牛津联队',
#   'season': '2025-2026',
#   'homeTeamId': 1061,
#   'matchId': 1678474,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 2,
#   'handicap': '1',
#   'jczqOdds': {'0': '1.48', '1': '3.75', '3': '5.35'},
#   'league': '英冠',
#   'euroOdds': {'0': '1.57', '1': '3.92', '3': '5.63'},
#   'matchTime': 1764360000000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20181012123514.png',
#   'jcMatchNo': '20251128012',
#   'minute': "0'",
#   'homeRank': '22',
#   'round': '第18轮',
#   'matchNo': '20251128012',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '2.28'}, {'1': '3.25'}, {'0': '2.62'}],
#    'spfOdds': [{'3': '5.35'}, {'1': '3.75'}, {'0': '1.48'}]},
#   'awayTeamId': 51,
#   'dc': 0},
#  {'awayTeam': '艾尔切',
#   'leagueColor': '#006633',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '1.62', 'option': '平'},
#    {'number': '0.99', 'option': '胜'},
#    {'number': '2.61', 'option': '负'}],
#   'viewpointsAsian': [{'amount': 14,
#     'nowBet': '平手/半球',
#     'nowOddsUp': '1.87',
#     'nowOddsDown': '1.99'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013121180614.jpg',
#   'asianOdds': {'nowBet': '平手/半球',
#    'handicap': '0.25',
#    'nowOddsUp': '1.87',
#    'nowOddsDown': '1.99'},
#   'leagueId': 26,
#   'awayRank': '10',
#   'homeTeam': '赫塔菲',
#   'season': '2025-2026',
#   'homeTeamId': 86,
#   'matchId': 1687895,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 4,
#   'handicap': '-1',
#   'jczqOdds': {'0': '3.75', '1': '2.70', '3': '2.03'},
#   'league': '西甲',
#   'euroOdds': {'0': '3.85', '1': '2.90', '3': '2.22'},
#   'matchTime': 1764360000000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20140818185717.png',
#   'jcMatchNo': '20251128013',
#   'minute': "0'",
#   'homeRank': '7',
#   'round': '第14轮',
#   'matchNo': '20251128013',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '4.85'}, {'1': '3.35'}, {'0': '1.60'}],
#    'spfOdds': [{'3': '2.03'}, {'1': '2.70'}, {'0': '3.75'}]},
#   'awayTeamId': 113,
#   'dc': 1},
#  {'awayTeam': 'AVS',
#   'leagueColor': '#006665',
#   'matchState': 0,
#   'focus': False,
#   'viewpointsAsian': [{'amount': 14,
#     'nowBet': '半球/一球',
#     'nowOddsUp': '1.93',
#     'nowOddsDown': '1.93'}],
#   'score': '0:0',
#   'asianOdds': {'nowBet': '半球/一球',
#    'handicap': '0.75',
#    'nowOddsUp': '1.93',
#    'nowOddsDown': '1.93'},
#   'leagueId': 20,
#   'awayRank': '18',
#   'homeTeam': '吉马雷斯',
#   'season': '2025-2026',
#   'homeTeamId': 816,
#   'matchId': 1694670,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 1,
#   'handicap': '-1',
#   'jczqOdds': {'0': '5.40', '1': '3.50', '3': '1.52'},
#   'league': '葡超',
#   'euroOdds': {'0': '5.26', '1': '3.63', '3': '1.65'},
#   'matchTime': 1764360900000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013128175741.jpg',
#   'jcMatchNo': '20251128014',
#   'minute': "0'",
#   'homeRank': '8',
#   'round': '第12轮',
#   'matchNo': '20251128014',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '2.80'}, {'1': '3.25'}, {'0': '2.16'}],
#    'spfOdds': [{'3': '1.52'}, {'1': '3.50'}, {'0': '5.40'}]},
#   'awayTeamId': 1231939,
#   'dc': 0},
#  {'awayTeam': '巴西国际',
#   'leagueColor': '#996600',
#   'matchState': 0,
#   'focus': False,
#   'viewpointsAsian': [{'amount': 13,
#     'nowBet': '平手/半球',
#     'nowOddsUp': '1.98',
#     'nowOddsDown': '1.87'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130913225428.png',
#   'asianOdds': {'nowBet': '平手/半球',
#    'handicap': '0.25',
#    'nowOddsUp': '1.98',
#    'nowOddsDown': '1.87'},
#   'leagueId': 4,
#   'awayRank': '15',
#   'homeTeam': '瓦斯科达伽马',
#   'season': '2025',
#   'homeTeamId': 411,
#   'matchId': 1617615,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 2,
#   'handicap': '-1',
#   'jczqOdds': {'0': '3.00', '1': '3.02', '3': '2.15'},
#   'league': '巴西甲',
#   'euroOdds': {'0': '3.15', '1': '3.23', '3': '2.24'},
#   'matchTime': 1764369000000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130913230856.png',
#   'jcMatchNo': '20251128015',
#   'minute': "0'",
#   'homeRank': '13',
#   'round': '第36轮',
#   'matchNo': '20251128015',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '4.75'}, {'1': '3.65'}, {'0': '1.55'}],
#    'spfOdds': [{'3': '2.15'}, {'1': '3.02'}, {'0': '3.00'}]},
#   'awayTeamId': 331,
#   'dc': 0},
#  {'awayTeam': '阿德莱德联',
#   'leagueColor': '#FF7000',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '1.17', 'option': '胜'},
#    {'number': '0.38', 'option': '平'},
#    {'number': '0.78', 'option': '负'}],
#   'viewpointsAsian': [{'amount': 13,
#     'nowBet': '受平手/半球',
#     'nowOddsUp': '2.02',
#     'nowOddsDown': '1.82'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130923112344.png',
#   'asianOdds': {'nowBet': '受平手/半球',
#    'handicap': '*0.25',
#    'nowOddsUp': '2.02',
#    'nowOddsDown': '1.82'},
#   'leagueId': 167969,
#   'awayRank': '3',
#   'homeTeam': '惠灵顿凤凰',
#   'season': '2025-2026',
#   'homeTeamId': 5153,
#   'matchId': 1748184,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 1,
#   'handicap': '1',
#   'jczqOdds': {'0': '1.89', '1': '3.54', '3': '3.15'},
#   'league': '澳超',
#   'euroOdds': {'0': '2.06', '1': '3.68', '3': '3.15'},
#   'matchTime': 1764388800000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20181011233716.jpg',
#   'jcMatchNo': '20251129001',
#   'minute': "0'",
#   'homeRank': '8',
#   'round': '第6轮',
#   'matchNo': '20251129001',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '1.69'}, {'1': '3.85'}, {'0': '3.60'}],
#    'spfOdds': [{'3': '3.15'}, {'1': '3.54'}, {'0': '1.89'}]},
#   'awayTeamId': 2440,
#   'dc': 1},
#  {'awayTeam': '长崎成功丸',
#   'leagueColor': '#33CC99',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '1.47', 'option': '平'},
#    {'number': '0.12', 'option': '负'},
#    {'number': '1.35', 'option': '胜'}],
#   'viewpointsAsian': [{'amount': 5,
#     'nowBet': '受平手/半球',
#     'nowOddsUp': '1.75',
#     'nowOddsDown': '2.09'},
#    {'amount': 10, 'nowBet': '平手', 'nowOddsUp': '2.06', 'nowOddsDown': '1.77'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013325134639.jpg',
#   'asianOdds': {'nowBet': '平手',
#    'handicap': '0',
#    'nowOddsUp': '2.06',
#    'nowOddsDown': '1.77'},
#   'leagueId': 208,
#   'awayRank': '1',
#   'homeTeam': '德岛漩涡',
#   'season': '2025',
#   'homeTeamId': 2701,
#   'matchId': 1585451,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 0,
#   'handicap': '1',
#   'jczqOdds': {'0': '2.25', '1': '3.25', '3': '2.65'},
#   'league': '日职乙',
#   'euroOdds': {'0': '2.40', '1': '3.10', '3': '2.82'},
#   'matchTime': 1764392400000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013319174626.jpg',
#   'jcMatchNo': '20251129002',
#   'minute': "0'",
#   'homeRank': '4',
#   'round': '第38轮',
#   'matchNo': '20251129002',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '1.50'}, {'1': '3.95'}, {'0': '4.76'}],
#    'spfOdds': [{'3': '2.65'}, {'1': '3.25'}, {'0': '2.25'}]},
#   'awayTeamId': 8966,
#   'dc': 0},
#  {'awayTeam': '班迪特斯磐城',
#   'leagueColor': '#33CC99',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '3.06', 'option': '负'},
#    {'number': '0.02', 'option': '平'},
#    {'number': '3.04', 'option': '胜'}],
#   'viewpointsAsian': [{'amount': 8,
#     'nowBet': '半球',
#     'nowOddsUp': '1.81',
#     'nowOddsDown': '2.00'},
#    {'amount': 6,
#     'nowBet': '半球/一球',
#     'nowOddsUp': '2.03',
#     'nowOddsDown': '1.82'}],
#   'score': '0:0',
#   'awayLogo': '',
#   'asianOdds': {'nowBet': '半球',
#    'handicap': '0.5',
#    'nowOddsUp': '1.81',
#    'nowOddsDown': '2.00'},
#   'leagueId': 208,
#   'awayRank': '9',
#   'homeTeam': '仙台维加泰',
#   'season': '2025',
#   'homeTeamId': 2676,
#   'matchId': 1585453,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 0,
#   'handicap': '-1',
#   'jczqOdds': {'0': '3.95', '1': '3.65', '3': '1.66'},
#   'league': '日职乙',
#   'euroOdds': {'0': '3.95', '1': '3.54', '3': '1.79'},
#   'matchTime': 1764392400000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013319173041.jpg',
#   'jcMatchNo': '20251129003',
#   'minute': "0'",
#   'homeRank': '6',
#   'round': '第38轮',
#   'matchNo': '20251129003',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '3.05'}, {'1': '3.50'}, {'0': '1.94'}],
#    'spfOdds': [{'3': '1.66'}, {'1': '3.65'}, {'0': '3.95'}]},
#   'awayTeamId': 22718,
#   'dc': 0},
#  {'awayTeam': '甲府风林',
#   'leagueColor': '#33CC99',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '19.62', 'option': '负'},
#    {'number': '7.57', 'option': '平'},
#    {'number': '12.04', 'option': '胜'}],
#   'viewpointsAsian': [{'amount': 7,
#     'nowBet': '半球',
#     'nowOddsUp': '1.78',
#     'nowOddsDown': '2.04'},
#    {'amount': 7,
#     'nowBet': '半球/一球',
#     'nowOddsUp': '2.02',
#     'nowOddsDown': '1.82'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013324162113.gif',
#   'asianOdds': {'nowBet': '半球',
#    'handicap': '0.5',
#    'nowOddsUp': '1.78',
#    'nowOddsDown': '2.04'},
#   'leagueId': 208,
#   'awayRank': '13',
#   'homeTeam': '熊本深红',
#   'season': '2025',
#   'homeTeamId': 6639,
#   'matchId': 1585446,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 0,
#   'handicap': '-1',
#   'jczqOdds': {'0': '4.18', '1': '3.62', '3': '1.63'},
#   'league': '日职乙',
#   'euroOdds': {'0': '4.37', '1': '3.36', '3': '1.75'},
#   'matchTime': 1764392400000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/2013318142157.jpg',
#   'jcMatchNo': '20251129004',
#   'minute': "0'",
#   'homeRank': '17',
#   'round': '第38轮',
#   'matchNo': '20251129004',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '3.05'}, {'1': '3.40'}, {'0': '1.97'}],
#    'spfOdds': [{'3': '1.63'}, {'1': '3.62'}, {'0': '4.18'}]},
#   'awayTeamId': 2660,
#   'dc': 0},
#  {'awayTeam': '秋田蓝色闪电',
#   'leagueColor': '#33CC99',
#   'matchState': 0,
#   'focus': False,
#   'distribution': [{'number': '6.60', 'option': '胜'},
#    {'number': '0.19', 'option': '平'},
#    {'number': '6.40', 'option': '负'}],
#   'viewpointsAsian': [{'amount': 12,
#     'nowBet': '平手/半球',
#     'nowOddsUp': '1.83',
#     'nowOddsDown': '2.00'}],
#   'score': '0:0',
#   'awayLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20121218210601.gif',
#   'asianOdds': {'nowBet': '平手/半球',
#    'handicap': '0.25',
#    'nowOddsUp': '1.83',
#    'nowOddsDown': '2.00'},
#   'leagueId': 208,
#   'awayRank': '14',
#   'homeTeam': '富山胜利',
#   'season': '2025',
#   'homeTeamId': 8864,
#   'matchId': 1585452,
#   'matchStateShow': '未开赛',
#   'matchNoteCount': 0,
#   'handicap': '-1',
#   'jczqOdds': {'0': '3.32', '1': '3.25', '3': '1.92'},
#   'league': '日职乙',
#   'euroOdds': {'0': '3.25', '1': '3.18', '3': '2.11'},
#   'matchTime': 1764392400000,
#   'homeLogo': 'https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/201332592817.jpg',
#   'jcMatchNo': '20251129005',
#   'minute': "0'",
#   'homeRank': '18',
#   'round': '第38轮',
#   'matchNo': '20251129005',
#   'liveEvent': [],
#   'exflag': 0,
#   'viewpoints': {'rqspfOdds': [{'3': '4.05'}, {'1': '3.50'}, {'0': '1.68'}],
#    'spfOdds': [{'3': '1.92'}, {'1': '3.25'}, {'0': '3.32'}]},
#   'awayTeamId': 12092,
#   'dc': 0}]

# %%
from dotenv import load_dotenv
load_dotenv()

from hyrule_football.tools import get_match_for_name
# print(get_match_for_name("桑托斯 VS 米拉索"))
# print(get_match_for_name("皇马"))
# print(get_match_for_name("桑托斯"))
# print(get_match_for_name("米拉索"))
# print(get_match_for_name("桑托斯vs米拉索"))
# print(get_match_for_name("桑托斯Vs 米拉索"))
# print(get_match_for_name("桑托斯&格雷米奥")) # 暂不支持吧
# Out:
# 2025-11-19 14:52:54 - hyrule_football.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯 VS 米拉索
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - hyrule_football.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：皇马
# 没有找到相关比赛，确认「皇马」比赛在「赛事列表」中
# 2025-11-19 14:52:54 - hyrule_football.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - hyrule_football.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：米拉索
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - hyrule_football.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯vs米拉索
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - hyrule_football.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯Vs 米拉索
# 桑托斯(主) VS 米拉索(客)
# 2025-11-19 14:52:54 - hyrule_football.tools.match_tools - INFO - >>> [Tool] get_match_for_name 被调用，入参：桑托斯&格雷米奥
# 没有找到相关比赛，确认「桑托斯&格雷米奥」比赛在「赛事列表」中
