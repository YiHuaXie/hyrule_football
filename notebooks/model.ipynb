# %%
{
    "awayRank": "[北部赛区C组1]",
    "awayTeamAbbEnName": "BRA",
    "awayTeamAbbName": "布拉德福",
    "awayTeamAllName": "布拉德福德",
    "awayTeamCode": "BRA",
    "awayTeamId": 68,
    "backColor": "ff3366",
    "baseAwayTeamId": 0,
    "baseHomeTeamId": 0,
    "bettingAllUp": 0,
    "bettingSingle": 0,
    "businessDate": "2025-11-11",
    "crs": {},
    "groupName": "",
    "had": {
        "a": "2.40",
        "af": "0",
        "d": "3.15",
        "df": "0",
        "goalLine": "",
        "goalLineValue": "",
        "h": "2.53",
        "hf": "0",
        "updateDate": "2025-11-11",
        "updateTime": "21:17:55",
    },
    "hafu": {},
    "hhad": {
        "a": "4.60",
        "af": "0",
        "d": "4.60",
        "df": "0",
        "goalLine": "+1",
        "goalLineValue": "+1.00",
        "h": "1.44",
        "hf": "0",
        "updateDate": "2025-11-11",
        "updateTime": "21:17:48",
    },
    "homeRank": "[北部赛区C组2]",
    "homeTeamAbbEnName": "DON",
    "homeTeamAbbName": "唐卡斯特",
    "homeTeamAllName": "唐卡斯特",
    "homeTeamCode": "DON",
    "homeTeamId": 73,
    "isHide": 0,
    "isHot": 0,
    "leagueAbbName": "英锦标赛",
    "leagueAllName": "英格兰锦标赛",
    "leagueCode": "ELT",
    "leagueId": 86,
    "lineNum": "",
    "matchDate": "2025-11-12",
    "matchId": 2035004,
    "matchName": "",
    "matchNum": 2001,
    "matchNumDate": "251111",
    "matchNumStr": "周二001",
    "matchStatus": "Selling",
    "matchTime": "03:00:00",
    "matchWeek": "周二",
    "oddsList": [
        {
            "a": "4.600",
            "d": "4.600",
            "goalLine": "+1",
            "goalLineF": "",
            "goalLineValue": "+1.00",
            "h": "1.440",
            "matchId": 0,
            "matchNum": 0,
            "odds": "",
            "poolCode": "HHAD",
            "poolId": 2168013,
            "updateDate": "2025-11-11",
            "updateTime": "21:17:48",
        },
        {
            "a": "2.400",
            "d": "3.150",
            "goalLine": "",
            "goalLineF": "",
            "goalLineValue": "",
            "h": "2.530",
            "matchId": 0,
            "matchNum": 0,
            "odds": "",
            "poolCode": "HAD",
            "poolId": 2168004,
            "updateDate": "2025-11-11",
            "updateTime": "21:17:55",
        },
    ],
    "poolList": [
        {
            "allUp": 0,
            "bettingAllup": 1,
            "bettingSingle": 0,
            "cbtAllUp": 0,
            "cbtSingle": 0,
            "cbtValue": 2,
            "fixedOddsgoalLine": "",
            "intAllUp": 0,
            "intSingle": 0,
            "intValue": 2,
            "matchId": 0,
            "matchNum": 0,
            "poolCloseDate": "",
            "poolCloseTime": "",
            "poolCode": "HHAD",
            "poolId": 2168013,
            "poolOddsType": "F",
            "poolStatus": "Selling",
            "sellInitialDate": "",
            "sellInitialTime": "",
            "single": 0,
            "updateDate": "",
            "updateTime": "",
            "vbtAllUp": 0,
            "vbtSingle": 0,
            "vbtValue": 0,
        },
        {
            "allUp": 0,
            "bettingAllup": 1,
            "bettingSingle": 1,
            "cbtAllUp": 0,
            "cbtSingle": 0,
            "cbtValue": 2,
            "fixedOddsgoalLine": "",
            "intAllUp": 0,
            "intSingle": 0,
            "intValue": 2,
            "matchId": 0,
            "matchNum": 0,
            "poolCloseDate": "",
            "poolCloseTime": "",
            "poolCode": "HAD",
            "poolId": 2168004,
            "poolOddsType": "F",
            "poolStatus": "Selling",
            "sellInitialDate": "",
            "sellInitialTime": "",
            "single": 0,
            "updateDate": "",
            "updateTime": "",
            "vbtAllUp": 0,
            "vbtSingle": 0,
            "vbtValue": 0,
        },
    ],
    "remark": "",
    "sellStatus": 2,
    "taxDateNo": "2511111",
    "ttg": {},
    "vote": {},
}
