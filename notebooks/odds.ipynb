# %%
from hyrule_football.standard_odds import StandardOdds
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate

# pydantic_parser = PydanticOutputParser(pydantic_object=StandardOdds)
# print(pydantic_parser.get_format_instructions())

# prompt = PromptTemplate(
#     template="回答用户的查询.\n{format_instructions}\n{query}\n",
#     input_variables=["query"],
#     partial_variables={"format_instructions": pydantic_parser.get_format_instructions()},
# )

# # print(json.dumps(data, indent=2, ensure_ascii=False))
# print("提示词模板:")
# print(json.dumps(prompt.model_dump(), indent=2, ensure_ascii=False))

# 组合链：Prompt → LLM → pydantic_parser 顺序不能瞎写奥
# chain = prompt | llm | pydantic_parser
# joke = chain.invoke({"query": "为我写一个搞笑的笑话"})
# print("输出内容：", joke)
# Out:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# ...
