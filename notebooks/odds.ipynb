# %%
from dotenv import load_dotenv
load_dotenv()

from hyrule_football.core.match_service import request_all_match_list

request_all_match_list()
# matches = get_match_for_name("桑托斯")
# if not matches:
#     exit(1)

# odds_info = get_odds_for_match(matches[0])
# print(json.dumps(odds_info.model_dump(), indent=4, ensure_ascii=False))
# Out:
# [MatchInfo(home='慕士达', away='沙尔克04', match_id='1680773', league='德乙'),
#  MatchInfo(home='柏德博恩', away='汉诺威96', match_id='1680772', league='德乙'),
#  MatchInfo(home='杜塞尔多夫', away='马格德堡', match_id='1680767', league='德乙'),
#  MatchInfo(home='伯恩利', away='切尔西', match_id='1670295', league='英超'),
#  MatchInfo(home='布里斯托城', away='斯旺西', match_id='1678454', league='英冠'),
#  MatchInfo(home='考文垂', away='西布罗姆维奇', match_id='1678446', league='英冠'),
#  MatchInfo(home='查尔顿', away='南安普敦', match_id='1678445', league='英冠'),
#  MatchInfo(home='阿拉维斯', away='塞尔塔', match_id='1687882', league='西甲'),
#  MatchInfo(home='红星', away='克莱蒙', match_id='1687587', league='法乙'),
#  MatchInfo(home='特罗姆瑟', away='罗森博格', match_id='1593025', league='挪超'),
#  MatchInfo(home='德咸科', away='阿尔纳泽马', match_id='1731567', league='沙特联'),
#  MatchInfo(home='乌迪内斯', away='博洛尼亚', match_id='1666893', league='意甲'),
#  MatchInfo(home='卡利亚里', away='热那亚', match_id='1666885', league='意甲'),
# ...
