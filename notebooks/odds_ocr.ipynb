# %%
from app.prompts.odds_orc_prompts import FIVE_LEAGUES_PROMPT, COMMON_LEAGUES_PROMPT
from app.chains.odds_ocr import odds_image_orc
from dotenv import load_dotenv

load_dotenv()

data = [
    # 德甲95
    # "https://neroexample.oss-cn-hangzhou.aliyuncs.com/%E5%BE%B7%E7%94%B295.png",
    # # 法甲 95 96
    # "https://neroexample.oss-cn-hangzhou.aliyuncs.com/%E6%B3%95%E7%94%B295.png",
    # "https://neroexample.oss-cn-hangzhou.aliyuncs.com/%E6%B3%95%E7%94%B296.png",
    # # 英超 95
    # "https://neroexample.oss-cn-hangzhou.aliyuncs.com/%E8%8B%B1%E8%B6%8595.png",
    # # 西甲 95
    # "https://neroexample.oss-cn-hangzhou.aliyuncs.com/%E8%A5%BF%E7%94%B295.png",
    # 通用
    "https://neroexample.oss-cn-hangzhou.aliyuncs.com/%E9%80%9A%E7%94%A894.jpg",
]

for image_url in data:
    odds_image_orc(image_instructions=COMMON_LEAGUES_PROMPT, image_url=image_url)

# %%
from app.chains.odds_ocr import generate_odds_list
from dotenv import load_dotenv

load_dotenv()

generate_odds_list("/Users/neroxie/Desktop/通用94.md")
# Out:
# 2025-11-20 16:08:40 - app.chains.odds_ocr - INFO - ✅ 已保存至 Redis，体系：通用94
