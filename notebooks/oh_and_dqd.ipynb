# %%
import hyrule_football.service.oh_service as oh
import hyrule_football.service.dqd_service as dqd
import json

result = oh.request_league_data()
print(json.dumps(result[0], indent=4, ensure_ascii=False))

result = dqd.request_league_data()
print(json.dumps(result[0], indent=4, ensure_ascii=False))

# %%
import hyrule_football.service.oh_service as oh
import hyrule_football.service.dqd_service as dqd
import json

oh_match_list = oh.request_match_list()
print(json.dumps(oh_match_list[0], indent=4, ensure_ascii=False))
dqd_match_list = dqd.request_app_daily_match_list()
print(json.dumps(dqd_match_list[0], indent=4, ensure_ascii=False))
# Out:
# 2025-12-21 17:22:36 - hyrule_football.service.oh_service - INFO - POST http://backend.aiball365.com/web/matchLiveList, params={'channel': 'web', 'os': 'browser', 'matchType': 1, 'page': 0, 'size': 10000, 'type': 1, 'leagues': None}
# {'matchType': 1, 'page': 0, 'size': 10000, 'type': 1, 'leagues': None}
# {
#     "awayTeam": "埃因霍温",
#     "leagueColor": "#FF6699",
#     "matchState": 0,
#     "focus": false,
#     "recommend": true,
#     "distribution": [
#         {
#             "number": "16.67",
#             "option": "胜"
#         },
#         {
#             "number": "5.58",
#             "option": "平"
#         },
#         {
#             "number": "11.08",
#             "option": "负"
#         }
#     ],
#     "viewpointsAsian": [
#         {
#             "amount": 13,
#             "nowBet": "受半球/一球",
#             "nowOddsUp": "1.87",
#             "nowOddsDown": "2.00"
#         }
#     ],
#     "score": "0:0",
#     "awayRedCard": 0,
#     "awayLogo": "https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404171257.jpg",
#     "asianOdds": {
#         "nowBet": "受半球/一球",
#         "handicap": "*0.75",
#         "nowOddsUp": "1.87",
#         "nowOddsDown": "2.00"
#     },
#     "leagueId": 16,
#     "homeRedCard": 0,
#     "awayRank": "1",
#     "homeTeam": "乌德勒支",
#     "season": "2025-2026",
#     "homeTeamId": 211,
#     "matchId": 1671931,
#     "matchStateShow": "未开赛",
#     "matchNoteCount": 12,
#     "handicap": "1",
#     "jczqOdds": {
#         "0": "1.62",
#         "1": "3.80",
#         "3": "4.07"
#     },
#     "league": "荷甲",
#     "euroOdds": {
#         "0": "1.76",
#         "1": "3.97",
#         "3": "4.05"
#     },
#     "matchTime": 1766315700000,
#     "homeLogo": "https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/team/20130404170511.jpg",
#     "jcMatchNo": "20251221001",
#     "minute": "0'",
#     "homeRank": "8",
#     "round": "第17轮",
#     "hasPermission": false,
#     "matchNo": "20251221001",
#     "liveEvent": [],
#     "exflag": 0,
#     "viewpoints": {
#         "rqspfOdds": [
#             {
#                 "3": "2.00"
#             },
#             {
#                 "1": "3.80"
#             },
#             {
#                 "0": "2.76"
#             }
#         ],
#         "spfOdds": [
#             {
#                 "3": "4.07"
#             },
#             {
#                 "1": "3.80"
#             },
#             {
#                 "0": "1.62"
#             }
#         ]
#     },
#     "awayTeamId": 224,
#     "dc": 0
# }
# {
#     "match_id": "54340714",
#     "competition": {
#         "id": "121",
#         "name": "希腊丙",
#         "area_id": "82",
#         "area_name": "希腊",
#         "color": "#FFCC88",
#         "sort": "9999"
#     },
#     "status": "Fixture",
#     "minute": "0",
#     "minute_str": "",
#     "injury_time": 0,
#     "start_play": "2025-12-21 13:00:00",
#     "match_timestamp": 1766322000,
#     "update_timestamp": 1766299213,
#     "period": "1H",
#     "cmp_type": "soccer",
#     "team_A": {
#         "id": "160882",
#         "name": "伊拉克塞尔马",
#         "logo": "https://sd.qunliao.info/fastdfs6/M00/58/C3/rBUESWSBnJyAasUrAAAl7k3F_g8900.png",
#         "fs": "",
#         "hts": "",
#         "league_rank": "0",
#         "yc": "",
#         "rc": "",
#         "ht_corner": "",
#         "corners": "",
#         "cond_odd": [
#             0,
#             0,
#             0
#         ]
#     },
#     "team_B": {
#         "id": "64700",
#         "name": "奥尔法诺",
#         "logo": "https://sd.qunliao.info/fastdfs6/M00/58/C3/rBUESWSBnJyAasUrAAAl7k3F_g8900.png",
#         "fs": "",
#         "hts": "",
#         "league_rank": "0",
#         "yc": "",
#         "rc": "",
#         "ht_corner": "",
#         "corners": "",
#         "cond_odd": [
#             0,
#             0,
#             0
#         ]
#     },
#     "animation_live": "https://tracker.namitiyu.com/zh/football?profile=yADdIyHoruqHP&id=4467285",
#     "business_status": 256,
#     "chatroom_num": "",
#     "forecast_num": "",
#     "hdp_odds": "无",
#     "total_odds": "无"
# }
