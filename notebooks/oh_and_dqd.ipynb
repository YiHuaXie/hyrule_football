# %%
import hyrule_football.service.oh_service as oh
import hyrule_football.service.dqd_service as dqd
import json

result = oh.request_league_data()
print(json.dumps(result[0], indent=4, ensure_ascii=False))

result = dqd.request_league_data()
print(json.dumps(result[0], indent=4, ensure_ascii=False))
# Out:
# {
#     "countryName": "欧洲赛事",
#     "continentName": "欧洲联赛",
#     "countryId": 31,
#     "continentId": 1,
#     "leagueLogo": "https://alphaball-production.oss-cn-beijing.aliyuncs.com/logo/league/20200411095945.jpg",
#     "continentLogo": "http://zq.win007.com/Image/info/images/2007122314194341880.gif",
#     "leagueId": 51,
#     "leagueName": "欧洲杯",
#     "countryLogo": "\nhttps://alphaball-production.oss-cn-beijing.aliyuncs.com/country/2007122314194341880.gif",
#     "cup": 1
# }
# {
#     "id": 1,
#     "label": "英超",
#     "logo": "",
#     "competition_id": "4",
#     "season_id": 24646,
#     "season": {
#         "title": "25/26",
#         "url": "https://sport-data.dongqiudi.com/soccer/biz/data/seasons?competition_id=4&app=dqd&version=0&platform=web&language=zh-cn&app_type=",
#         "type": ""
#     },
#     "position": 1,
#     "last_modify": 1765534866,
#     "country_code": "gb",
#     "sub_tabs": [
#         {
#             "title": "积分",
# ...
