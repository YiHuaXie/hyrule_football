# %%
from hyrule_football.service.api_service import request_daily_match_list
request_daily_match_list()

# %%
from hyrule_football.service.api_service import request_hot_match_list
request_hot_match_list()

# %%
from hyrule_football.service.api_service import request_league_list
request_league_list()

# %%
from hyrule_football.service.api_service import request_euro_odds_detail
match_id = "1748183"
request_euro_odds_detail(match_id)

# %%
from hyrule_football.service.api_service import request_asia_odds_detail
match_id = "1748183"
request_asia_odds_detail(match_id)
# Out:
# 2025-11-28 15:41:34 - hyrule_football.service.api_service - INFO - POST http://backend.aiball365.com/web/asiaOdds, params={'channel': 'web', 'os': 'browser', 'matchId': '1748183'}
# {'companyList': {'交易所': [],
#   '中文': [{'cname': '皇冠', 'type': 0, 'nameGroup': '中文', 'cid': 112},
#    {'cname': '伟德', 'type': 1, 'nameGroup': '中文', 'cid': 1},
#    {'cname': '澳门', 'type': 0, 'nameGroup': '中文', 'cid': 90},
#    {'cname': '易胜博', 'type': 0, 'nameGroup': '中文', 'cid': 17},
#    {'cname': '盈禾', 'type': 0, 'nameGroup': '中文', 'cid': 103},
#    {'cname': '明陞', 'type': 0, 'nameGroup': '中文', 'cid': 87},
#    {'cname': '利记', 'type': 0, 'nameGroup': '中文', 'cid': 74},
#    {'cname': '金宝博', 'type': 0, 'nameGroup': '中文', 'cid': 52},
#    {'cname': '威廉希尔', 'type': 1, 'nameGroup': '中文', 'cid': 26},
#    {'cname': '平博', 'type': 0, 'nameGroup': '中文', 'cid': 181},
#    {'cname': '香港马会', 'type': 0, 'nameGroup': '中文', 'cid': 46}],
#   '主流公司': [{'cname': '伟德', 'type': 1, 'nameGroup': '中文', 'cid': 1},
# ...
